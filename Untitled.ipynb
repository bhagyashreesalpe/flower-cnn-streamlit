# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import load_img,ImageDataGenerator
from tensorflow.keras.models import Sequential,load_model
from tensorflow.keras.layers import Conv2D, MaxPooling2D,Dense,Dropout,Flatten

# %% [markdown]
# # fetch images count from folders

# %%
count = 0 
dirs = os.listdir('Images/')
for dir in dirs :
    files = list(os.listdir('images/'+dir))
    print(dir + 'Folder has ' + str(len(files)) + 'images')
    count = count + len(files)
print('images Folder has ' + str(count) + 'images')
# Out:
# daisyFolder has 764images
# dandelionFolder has 1052images
# roseFolder has 784images
# sunflowerFolder has 733images
# tulipFolder has 984images
# images Folder has 4317images

# %% [markdown]
# # Load images into Arrays as Dataset

# %%
base_dir = 'images/'
img_size = 180
batch = 32

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(base_dir,
                                                        seed = 123,
                                                        validation_split = 0.2,
                                                        subset = 'training',
                                                        batch_size = batch,
                                                        image_size = (img_size,img_size))

val_ds = tf.keras.utils.image_dataset_from_directory(base_dir,
                                                        seed = 123,
                                                        validation_split = 0.2,
                                                        subset = 'validation',
                                                        batch_size = batch,
                                                        image_size = (img_size,img_size))
# Out:
# Found 4317 files belonging to 5 classes.
# Using 3454 files for training.
# Found 4317 files belonging to 5 classes.
# Using 863 files for validation.

# %%
flower_names = train_ds.class_names
flower_names
# Out:
# ['daisy', 'dandelion', 'rose', 'sunflower', 'tulip']

# %%
import matplotlib.pyplot as plt

# %%
i = 0 
plt.figure(figsize=(10,10))


for images,labels in train_ds.take(1):
    for i in range(9):
        plt.subplot(3,3,i+1)
        plt.imshow(images[i].numpy().astype('uint8'))
        plt.title(flower_names[labels[i]])
        plt.axis('off')

# %%
AUTOTUNE = tf.data.AUTOTUNE

# %%
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size = AUTOTUNE)

# %%
val_ds = val_ds.cache().prefetch(buffer_size = AUTOTUNE)

# %% [markdown]
# # DATA Augmentation

# %%
data_augmentaion = Sequential([
    layers.RandomFlip("horizontal",input_shape = (img_size,img_size,3)),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1)

])

# %%
i = 0 
plt.figure(figsize=(10,10))


for images,labels in train_ds.take(1):
    for i in range(9):
        images = data_augmentaion(images)

        
        plt.subplot(3,3,i+1)
        plt.imshow(images[i].numpy().astype('uint8'))
        plt.axis('off')

# %% [markdown]
# # model creation

# %%
model = Sequential([
    data_augmentaion,
    layers.Rescaling(1./255),
    Conv2D(16,3,padding = 'same',activation ='relu'),
    MaxPooling2D(),
    Conv2D(32,3,padding = 'same',activation = 'relu'),
    MaxPooling2D(),
    Conv2D(64,3,padding = 'same',activation = 'relu'),
    MaxPooling2D(),
    Dropout(0.2),
    Flatten(),
    Dense(128,activation = 'relu'),
    Dense(5)

])

# %%
model.compile(optimizer ='adam',
              loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics = ['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_9 (Sequential)   (None, 180, 180, 3)       0
#
#  rescaling_6 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_13 (Conv2D)          (None, 180, 180, 16)      448
#
#  max_pooling2d_12 (MaxPoolin  (None, 90, 90, 16)       0
#  g2D)
#
#  conv2d_14 (Conv2D)          (None, 90, 90, 32)        4640
#
#  max_pooling2d_13 (MaxPoolin  (None, 45, 45, 32)       0
#  g2D)
#
#  conv2d_15 (Conv2D)          (None, 45, 45, 64)        18496
#
#  max_pooling2d_14 (MaxPoolin  (None, 22, 22, 64)       0
#  g2D)
#
#  dropout_4 (Dropout)         (None, 22, 22, 64)        0
#
#  flatten_4 (Flatten)         (None, 30976)             0
#
#  dense_8 (Dense)             (None, 128)               3965056
#
#  dense_9 (Dense)             (None, 5)                 645
#
# =================================================================
# Total params: 3,989,285
# Trainable params: 3,989,285
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(train_ds, epochs = 15,validation_data=val_ds)
# Out:
# Epoch 1/15
# 108/108 [==============================] - 185s 2s/step - loss: 1.5292 - accuracy: 0.3156 - val_loss: 1.3649 - val_accuracy: 0.4508
# Epoch 2/15
# 108/108 [==============================] - 177s 2s/step - loss: 1.1668 - accuracy: 0.5266 - val_loss: 1.0076 - val_accuracy: 0.5956
# Epoch 3/15
# 108/108 [==============================] - 157s 1s/step - loss: 1.0098 - accuracy: 0.5993 - val_loss: 0.9519 - val_accuracy: 0.6257
# Epoch 4/15
# 108/108 [==============================] - 167s 2s/step - loss: 0.9403 - accuracy: 0.6323 - val_loss: 0.9502 - val_accuracy: 0.6280
# Epoch 5/15
# 108/108 [==============================] - 142s 1s/step - loss: 0.8867 - accuracy: 0.6627 - val_loss: 0.9082 - val_accuracy: 0.6408
# Epoch 6/15
# 108/108 [==============================] - 124s 1s/step - loss: 0.8368 - accuracy: 0.6726 - val_loss: 0.8762 - val_accuracy: 0.6570
# Epoch 7/15
# 108/108 [==============================] - 119s 1s/step - loss: 0.7995 - accuracy: 0.6943 - val_loss: 0.8164 - val_accuracy: 0.6848
# Epoch 8/15
# 108/108 [==============================] - 117s 1s/step - loss: 0.7507 - accuracy: 0.7189 - val_loss: 0.7587 - val_accuracy: 0.7092
# Epoch 9/15
# 108/108 [==============================] - 130s 1s/step - loss: 0.7150 - accuracy: 0.7328 - val_loss: 0.8037 - val_accuracy: 0.7057
# Epoch 10/15
# 108/108 [==============================] - 148s 1s/step - loss: 0.6827 - accuracy: 0.7374 - val_loss: 0.9267 - val_accuracy: 0.6582
# Epoch 11/15
# 108/108 [==============================] - 162s 2s/step - loss: 0.6672 - accuracy: 0.7496 - val_loss: 0.7668 - val_accuracy: 0.7103
# Epoch 12/15
# 108/108 [==============================] - 174s 2s/step - loss: 0.6358 - accuracy: 0.7594 - val_loss: 0.7438 - val_accuracy: 0.7277
# Epoch 13/15
# 108/108 [==============================] - 139s 1s/step - loss: 0.5865 - accuracy: 0.7727 - val_loss: 0.7607 - val_accuracy: 0.7277
# Epoch 14/15
# 108/108 [==============================] - 117s 1s/step - loss: 0.6023 - accuracy: 0.7690 - val_loss: 0.7320 - val_accuracy: 0.7381
# Epoch 15/15
# 108/108 [==============================] - 114s 1s/step - loss: 0.5718 - accuracy: 0.7800 - val_loss: 0.8357 - val_accuracy: 0.7242

# %%
def classify_images(image_path):
    input_image = tf.keras.utils.load_img(image_path ,target_size =(180,180))
    input_image_array = tf.keras.utils.img_to_array(input_image)
    input_image_exp_dim = tf.expand_dims(input_image_array,0)

    predictions = model.predict(input_image_exp_dim)
    result = tf.nn.softmax(predictions[0])
    outcome = 'The Image belongs to' + flower_names[np.argmax(result)] + 'with a score of' + str(max(result)*100)
    return outcome

# %%
classify_images('C:/Users/admin/Documents/Deep_learning/project_flower_Dl/flower_reconazetion/samples/rose.jpg')
# Out:
# 1/1 [==============================] - 0s 63ms/step
# 'The Image belongs torosewith a score oftf.Tensor(75.11944, shape=(), dtype=float32)'

# %%
model.save('Flower_Recog_model.h5')
